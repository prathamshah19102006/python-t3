# %%
import requests,json
import pandas as pd

# %%
API_key='05a197e7d5989fc3e3a43696aef5097f'
city_name='ahmedabad'
url=f'http://api.openweathermap.org/geo/1.0/direct?q={city_name}&appid={API_key}'
res=requests.get(url)
res.status_code
# Out:
# 200

# %%
result=res.json()
result
# Out:
# [{'name': 'Ahmedabad',
#   'local_names': {'kn': 'ಅಹ್ಮದಾಬಾದ್',
#    'eo': 'Ahmadabado',
#    'zh': '艾哈迈达巴德',
#    'mr': 'अहमदाबाद',
#    'hi': 'अहमदाबाद',
#    'te': 'అహ్మదాబాద్',
#    'tt': 'Әхмәтабад',
#    'ne': 'अहमदाबाद',
#    'feature_name': 'Ahmedabad',
#    'he': 'אחמדאבאד',
#    'pa': 'ਅਹਿਮਦਾਬਾਦ',
#    'oc': 'Ahmadabad',
#    'or': 'ଅହମଦାବାଦ',
#    'pl': 'Ahmadabad',
#    'cs': 'Ahmadábád',
#    'ur': 'احمد آباد',
#    'en': 'Ahmedabad',
#    'ml': 'അഹമ്മദാബാദ്',
#    'ta': 'அகமதாபாத்',
#    'ar': 'أحمد آباد',
#    'ascii': 'Ahmedabad',
#    'bn': 'আহমেদাবাদ',
#    'uk': 'Ахмедабад',
#    'ru': 'Ахмадабад',
#    'de': 'Ahmedabad',
#    'gu': 'અમદાવાદ',
#    'ja': 'アフマダーバード'},
#   'lat': 23.0215374,
#   'lon': 72.5800568,
#   'country': 'IN',
#   'state': 'Gujarat'}]

# %%
lat=result[0]['lat']
lon=result[0]['lon']

# %%
lat,lon
# Out:
# (23.0215374, 72.5800568)

# %%
API_key='05a197e7d5989fc3e3a43696aef5097f'
city_name='ahmedabad'
url=f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}'
res=requests.get(url)
res.status_code
# Out:
# 200

# %%
result=res.json()
result
# Out:
# {'coord': {'lon': 72.5801, 'lat': 23.0215},
#  'weather': [{'id': 711,
#    'main': 'Smoke',
#    'description': 'smoke',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 300.19,
#   'feels_like': 301.07,
#   'temp_min': 300.19,
#   'temp_max': 300.19,
#   'pressure': 1009,
#   'humidity': 57,
#   'sea_level': 1009,
#   'grnd_level': 1004},
#  'visibility': 4000,
#  'wind': {'speed': 1.54, 'deg': 220},
#  'clouds': {'all': 20},
#  'dt': 1780372979,
#  'sys': {'type': 1,
#   'id': 9049,
#   'country': 'IN',
#   'sunrise': 1780359839,
#   'sunset': 1780408295},
#  'timezone': 19800,
#  'id': 1279233,
#  'name': 'Ahmedabad',
#  'cod': 200}

# %%
temp=result['main']['temp']
temp_min=result['main']['temp_min']
temp_max=result['main']['temp_max']
humidity=result['main']['humidity']
pressure=result['main']['pressure']
wind_speed=result['wind']['speed cvjn]
cloud_cover=result['clouds']['all']
temp,temp_min,temp_max,humidity,pressure,wind_speed,cloud_cover
# Out:
# (300.19, 300.19, 300.19, 57, 1009, 1.54, 20)

# %%
print(json.dumps(result,indent=5))
# Out:
# {
#      "coord": {
#           "lon": 72.5801,
#           "lat": 23.0215
#      },
#      "weather": [
#           {
#                "id": 711,
#                "main": "Smoke",
#                "description": "smoke",
#                "icon": "50d"
#           }
#      ],
#      "base": "stations",
#      "main": {
#           "temp": 300.19,
#           "feels_like": 301.07,
#           "temp_min": 300.19,
#           "temp_max": 300.19,
#           "pressure": 1009,
#           "humidity": 57,
#           "sea_level": 1009,
#           "grnd_level": 1004
#      },
#      "visibility": 4000,
#      "wind": {
#           "speed": 1.54,
#           "deg": 220
#      },
#      "clouds": {
#           "all": 20
#      },
#      "dt": 1780372979,
#      "sys": {
#           "type": 1,
#           "id": 9049,
#           "country": "IN",
#           "sunrise": 1780359839,
#           "sunset": 1780408295
#      },
#      "timezone": 19800,
#      "id": 1279233,
# ...

# %%
API_key='05a197e7d5989fc3e3a43696aef5097f'
city_name='ahmedabad'
url=f'https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={API_key}'
res=requests.get(url)
res.status_code
result=res.json()
result
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1780380000,
#    'main': {'temp': 302.19,
#     'feels_like': 304.41,
#     'temp_min': 302.19,
#     'temp_max': 310.21,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1002,
#     'humidity': 61,
#     'temp_kf': -8.02},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 3.71, 'deg': 226, 'gust': 4.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-06-02 06:00:00'},
#   {'dt': 1780390800,
#    'main': {'temp': 306.07,
#     'feels_like': 309,
#     'temp_min': 306.07,
#     'temp_max': 313.83,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 999,
#     'humidity': 49,
#     'temp_kf': -7.76},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
# ...

# %%
temp=result['list'][0]['main']['temp']
temp
data={'temp':[],'pressure':[],'humidity':[]}
for i in result['list']:
    data['temp'].append(i['main']['temp'])
    data['pressure'].append(i['main']['pressure'])
    data['humidity'].append(i['main']['humidity'])

# %%
len(data['temp'])
# Out:
# 40

# %%
df=pd.DataFrame(data)
df
# Out:
#       temp  pressure  humidity
# 0   302.19      1008        61
# 1   306.07      1007        49
# 2   310.36      1003        34
# 3   305.97      1004        50
# 4   304.60      1005        60
# 5   304.94      1004        56
# 6   304.06      1005        59
# 7   305.45      1006        54
# 8   310.17      1005        39
# 9   314.50      1001        27
# 10  313.38      1000        29
# 11  305.80      1002        53
# 12  300.98      1006        62
# 13  301.63      1003        65
# 14  303.75      1003        56
# 15  305.20      1005        51
# 16  310.04      1004        36
# 17  314.01      1001        27
# 18  311.46      1000        33
# 19  306.20      1002        53
# 20  306.78      1003        47
# 21  304.78      1003        55
# 22  304.05      1003        58
# 23  306.04      1005        49
# 24  310.56      1004        35
# 25  314.00      1001        26
# 26  312.48      1000        31
# 27  306.90      1002        48
# 28  307.43      1003        48
# ...
